# %%
import numpy as np
from astropy.io import fits
import astropy.units as u
from IPython.display import clear_output
from pathlib import Path
from importlib import reload
import time
import os

import cupy as cp

import poppy
from poppy.poppy_core import PlaneType

import misc

# set debugging mode for more information from POPPY as propagation is performed
import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

wavelength = 500e-9*u.m

# %% [markdown]
# # Timing an arbitrary Fraunhofer system.

# %%
poppy_log.disabled = False

npix = 256
oversample = 4

diam = 2.4*u.m

circ_pupil = poppy.CircularAperture(radius=diam/2)
asym_sec_obs = poppy.AsymmetricSecondaryObscuration(secondary_radius=diam/5, support_angle=(60, 180, 300), 
                                                    support_width=0.1*u.m, support_offset_x=0.0, support_offset_y=0.0,)
compound_pupil = poppy.CompoundAnalyticOptic(opticslist=[circ_pupil, asym_sec_obs])

scalar_trans_image = poppy.ScalarTransmission(planetype=PlaneType.image)
zern_wfe = poppy.ZernikeWFE(coefficients=[0,0,0,0,0,0,0,0,wavelength.value/40], radius=diam/2, aperture_stop=True)

osys = poppy.OpticalSystem(pupil_diameter=diam, npix=npix, oversample=oversample)

osys.add_pupil(compound_pupil)
osys.add_image(scalar_trans_image)
osys.add_pupil(zern_wfe)
osys.add_detector(pixelscale=0.020, fov_arcsec=4.0)

psf = osys.calc_psf(wavelength=wavelength,)
misc.myimshow(psf[0].data, npix=npsf, pxscl=psf[0].header['PIXELSCL']*u.arcsec/u.pix, lognorm=True,)
# Out:
# INFO:poppy:Initialized OpticalSystem: unnamed system
# INFO:poppy:Added pupil plane: unnamed
# INFO:poppy:Added image plane: -empty-
# INFO:poppy:Added pupil plane: Zernike WFE
# INFO:poppy:Added detector with pixelscale=0.02 and oversampling=4: Detector
# INFO:poppy:Calculating PSF with 1 wavelengths
# INFO:poppy: Propagating wavelength = 5e-07 m
# DEBUG:poppy:Input wavefront has wavelength=5e-07 m, npix=256, diam=2.4, pixel scale=0.00937 meters/pixel
# DEBUG:poppy:  Wavefront and optic unnamed already at same plane type, no propagation needed.
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: unnamed
# DEBUG:poppy:normalizing at first plane (entrance pupil) to 1.0 total intensity
# DEBUG:poppy:  Propagating wavefront to Image plane: -empty-.
# DEBUG:poppy:    Padded WF array for oversampling by 4x
# DEBUG:poppy:using numpy FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.014896 s, full function  in 0.021 s
# DEBUG:poppy:  Multiplied WF by phasor for Image plane: -empty-
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Zernike WFE.
# DEBUG:poppy:using numpy FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.013459 s, full function  in 0.018 s
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Zernike WFE
# DEBUG:poppy:  Propagating wavefront to Detector plane: Detector (200x200 pixels, 0.020 arcsec / pix).
# DEBUG:poppy:MatrixFourierTransform initialized using centering type = ADJUSTABLE
# DEBUG:poppy:    Propagating w/ MFT: 0.0050 arcsec / pix     fov=93.084 lam/D    npix=800
# DEBUG:poppy:      MFT method = ADJUSTABLE
# DEBUG:poppy:Forward MatrixFourierTransform: array shape (256, 256), centering style ADJUSTABLE, output region size 93.0842267730309 in lambda / D units, output array size 800.0 pixels, offset None
# DEBUG:poppy:     Result wavefront: at=after Zernike WFE shape=(800, 800)
# INFO:poppy:  Calculation completed in 0.946 s
# INFO:poppy:PSF Calculation completed.

# %%
poppy.conf.use_cupy = False
poppy.conf.use_mkl = False
poppy.conf.use_fftw = False

poppy_log.disabled = True

npix = 256
oversample = 16

diam = 2.4*u.m

circ_pupil = poppy.CircularAperture(radius=diam/2)
asym_sec_obs = poppy.AsymmetricSecondaryObscuration(secondary_radius=diam/5, support_angle=(60, 180, 300), 
                                                    support_width=0.1*u.m, support_offset_x=0.0, support_offset_y=0.0,)
compound_pupil = poppy.CompoundAnalyticOptic(opticslist=[circ_pupil, asym_sec_obs])

scalar_trans_image = poppy.ScalarTransmission(planetype=PlaneType.image)
zern_wfe = poppy.ZernikeWFE(coefficients=[0,0,0,0,0,0,0,0,wavelength.value/40], radius=diam/2, aperture_stop=True)

osys = poppy.OpticalSystem(pupil_diameter=diam, npix=npix, oversample=oversample)

osys.add_pupil(compound_pupil)
osys.add_image(scalar_trans_image)
osys.add_pupil(zern_wfe)
osys.add_detector(pixelscale=0.020, fov_arcsec=4.0)

# %%
# %%timeit
psf = osys.calc_psf(wavelength=wavelength,)
# Out:
# 15.8 s ± 52.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Timing the HST Fresnel system.

# %%
poppy_log.disabled = False

npix = 256
oversample = 8

# HST example - Following example in PROPER Manual V2.0 page 49.
diam = 2.4 * u.m
fl_pri = 5.52085 * u.m
d_pri_sec = 4.907028205 * u.m
fl_sec = -0.6790325 * u.m
d_sec_to_focus = 6.3919974 * u.m

hst = poppy.FresnelOpticalSystem(pupil_diameter=2.4*u.m, npix=npix, beam_ratio=1/oversample)
m1 = poppy.QuadraticLens(fl_pri, name='Primary')
m2 = poppy.QuadraticLens(fl_sec, name='Secondary')

hst.add_optic(poppy.CircularAperture(radius=diam.value/2))
hst.add_optic(poppy.SecondaryObscuration(secondary_radius=0.396,
                                 support_width=0.0264,
                                 support_angle_offset=45.0))
hst.add_optic(m1)
hst.add_optic(m2, distance=d_pri_sec)
hst.add_optic(poppy.ScalarTransmission(planetype=PlaneType.image, name='focus'), distance=d_sec_to_focus)

psf = hst.calc_psf(wavelength=wavelength)
misc.myimshow(psf[0].data, npix=npsf, pxscl=psf[0].header['PIXELSCL']*u.arcsec/u.pix, lognorm=True,)
# Out:
# INFO:poppy:Initialized OpticalSystem: unnamed system
# DEBUG:poppy:Initialized: Primary, fl =5.52e+00 m
# DEBUG:poppy:Initialized: Secondary, fl =-6.79e-01 m
# INFO:poppy:Added optic: Circle, radius=1.2 m after separation: 0.00e+00 m
# INFO:poppy:Added optic: Secondary Obscuration with 4 supports after separation: 0.00e+00 m
# INFO:poppy:Added optic: Primary after separation: 0.00e+00 m
# INFO:poppy:Added optic: Secondary after separation: 4.91e+00 m
# INFO:poppy:Added optic: focus after separation: 6.39e+00 m
# INFO:poppy:Calculating PSF with 1 wavelengths
# INFO:poppy: Propagating wavelength = 5e-07 m
# DEBUG:poppy:Padded WF array for oversampling by 8.000, to (2048, 2048).
# DEBUG:poppy:Input wavefront has wavelength=0.5 microns, npix=256, diam=2.4 m, pixel scale=0.009375 m / pix
# DEBUG:poppy:  Propagating wavefront to Optic: Circle, radius=1.2 m after distance 0.0 m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Circle, radius=1.2 m
# DEBUG:poppy:normalizing at first plane (entrance pupil) to 1.0 total intensity
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Secondary Obscuration with 4 supports after distance 0.0 m
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Secondary Obscuration with 4 supports
# DEBUG:poppy:  Propagating wavefront to Lens: Primary, with focal length 5.52085 m after distance 0.0 m
# DEBUG:poppy:------ Applying Lens: Primary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.200e+00 m, z_w0=0.000e+00 m
# z=0.000e+00 m, z_r=9.048e+06 m
# DEBUG:poppy:  Beam radius at Primary =1.20e+00 m
# DEBUG:poppy: input flat wavefront and Primary has output beam curvature of =-5.52e+00 m
# DEBUG:poppy:Primary has a curvature of =-5.52e+00 m
# DEBUG:poppy:Primary has a curved output wavefront, with waist at 5.520849999997944 m
# DEBUG:poppy:Post Optic Parameters:w_0:7.322e-07 m, z_w0=5.521e+00 m
# z=0.000e+00 m, z_r=3.369e-06 m
# DEBUG:poppy:Set output beam focal length to 5.52085 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =1.48e+13 m
# DEBUG:poppy:Applying spherical lens phase =6.75e-14 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Primary
# DEBUG:poppy:------ Optic: Primary applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: Secondary, with focal length -0.6790325 m after distance 4.907028205 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.520849999997944 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.009375 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=5.520849999997944 m
# DEBUG:poppy:using mkl_fft FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.094855 s, full function  in 0.103 s
# DEBUG:poppy:Applying spherical phase curvature =5.52e+00 m
# DEBUG:poppy:Applying spherical lens phase =1.81e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.4377213541661314e-07 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.6138217949979445 m
# DEBUG:poppy:Applying spherical phase curvature =-6.14e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.63e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.094260 s, full function  in 0.103 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 4.91e+00 m ------
# DEBUG:poppy:------ Applying Lens: Secondary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:7.322e-07 m, z_w0=5.521e+00 m
# z=4.907e+00 m, z_r=3.369e-06 m
# DEBUG:poppy:  Beam radius at Secondary =1.33e-01 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:7.322e-07 m, z_w0=5.521e+00 m
# z=4.907e+00 m, z_r=3.369e-06 m
# DEBUG:poppy: input curved wavefront and Secondary has output beam curvature of =-6.39e+00 m
# DEBUG:poppy:Secondary has a curvature of =-6.39e+00 m
# DEBUG:poppy:Secondary has a curved output wavefront, with waist at 11.2986926835285 m
# DEBUG:poppy:Post Optic Parameters:w_0:7.625e-06 m, z_w0=1.130e+01 m
# z=4.907e+00 m, z_r=3.653e-04 m
# DEBUG:poppy:Magnification: 10.412899234743197  from R_in = -0.6138217949979445 m, R_out = -6.3916644994027925 m
# DEBUG:poppy:Output beam focal length is now 57.48805474013198 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=-1.4727e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=-1.6291e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-1.5645e-01 1 / m
# DEBUG:poppy:Applying spherical phase curvature =2.17e+09 m
# DEBUG:poppy:Applying spherical lens phase =4.62e-10 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Secondary
# DEBUG:poppy:------ Optic: Secondary applied ------
# DEBUG:poppy:  Propagating wavefront to Image plane: focus after distance 6.3919974 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.2986926835285 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=6.391664478528501 m
# DEBUG:poppy:using mkl_fft FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.095708 s, full function  in 0.104 s
# DEBUG:poppy:Applying spherical phase curvature =6.39e+00 m
# DEBUG:poppy:Applying spherical lens phase =1.56e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.092783 s, full function  in 0.102 s
# DEBUG:poppy:using mkl_fft FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.095363 s, full function  in 0.105 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.13e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Image plane: focus
# INFO:poppy:  Calculation completed in 3.157 s
# INFO:poppy:PSF Calculation completed.

# %%
poppy.conf.use_cupy = False
poppy.conf.use_mkl = True
poppy.conf.use_fftw = False

poppy_log.disabled = True

npix = 256
oversample = 16

# HST example - Following example in PROPER Manual V2.0 page 49.
diam = 2.4 * u.m
fl_pri = 5.52085 * u.m
d_pri_sec = 4.907028205 * u.m
fl_sec = -0.6790325 * u.m
d_sec_to_focus = 6.3919974 * u.m

hst = poppy.FresnelOpticalSystem(pupil_diameter=2.4*u.m, npix=npix, beam_ratio=1/oversample)
m1 = poppy.QuadraticLens(fl_pri, name='Primary')
m2 = poppy.QuadraticLens(fl_sec, name='Secondary')

hst.add_optic(poppy.CircularAperture(radius=diam.value/2))
hst.add_optic(poppy.SecondaryObscuration(secondary_radius=0.396,
                                 support_width=0.0264,
                                 support_angle_offset=45.0))
hst.add_optic(m1)
hst.add_optic(m2, distance=d_pri_sec)
hst.add_optic(poppy.ScalarTransmission(planetype=PlaneType.image, name='focus'), distance=d_sec_to_focus)

# %%
# %%timeit
psf = hst.calc_psf(wavelength=wavelength,)
# Out:
# 15.2 s ± 100 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
