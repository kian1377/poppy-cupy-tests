# %%
import numpy as np
from astropy.io import fits
import astropy.units as u
from IPython.display import clear_output
from pathlib import Path
from importlib import reload
import time
import os

import cupy as cp

import poppy
from poppy.poppy_core import PlaneType

import misc

# set debugging mode for more information from POPPY as propagation is performed
import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = False

import poppy_optics
clear_output()

# %% [markdown]
# # Test all the optics with GPU by setting configuration for CuPy to True.

# %%
poppy.conf.use_cupy = True

reload(poppy_optics)
from poppy_optics import *
# Out:
# DEBUG:poppy:Initialized: Primary, fl =5.52e+00 m
# DEBUG:poppy:Initialized: Secondary, fl =-6.79e-01 m
# DEBUG:poppy:Trans: fits-files/roman_pupil_309.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:Roman Pupil: Loaded amplitude transmission from fits-files/roman_pupil_309.fits
# DEBUG:poppy:  Getting pixel scale from user-provided float value: 0.007741935483870968
# DEBUG:poppy:Trans: None
# DEBUG:poppy:OPD: fits-files/roman_primary_opd_529.fits
# DEBUG:poppy:No transmission supplied - will assume uniform throughput = 1
# INFO:poppy:Roman Primary OPD: Loaded OPD from fits-files/roman_primary_opd_529.fits
# INFO:poppy:No info supplied on amplitude transmission; assuming uniform throughput = 1
# DEBUG:poppy:  Getting pixel scale from user-provided float value: 0.004536862003780718
# DEBUG:poppy:Trans: fits-files/roman_pupil_309.fits
# DEBUG:poppy:OPD: fits-files/roman_primary_opd_309.fits
# INFO:poppy:Roman Primary: Loaded amplitude transmission from fits-files/roman_pupil_309.fits
# INFO:poppy:Roman Primary: Loaded OPD from fits-files/roman_primary_opd_309.fits
# DEBUG:poppy:  Getting pixel scale from user-provided float value: 0.007741935483870968
# INFO:poppy:Initialized OpticalSystem: unnamed system
# INFO:poppy:Initialized OpticalSystem: unnamed system
# INFO:poppy:Loaded influence function from /groups/douglase/kians-data-files/roman-cgi-phasec-data/dm-acts/proper_inf_func.fits for DM
# DEBUG:poppy:Initialized: Relay to/from Pupil, fl =1.00e+00 m
# DEBUG:poppy:Padded WF array for oversampling by 4.000, to (1024, 1024).
# DEBUG:poppy:Padded WF array for oversampling by 4.000, to (1024, 1024).

# %% [markdown]
# # Test creating a fixed sampling optic in order.
# Useful for debugging to ensure the amplitude/transmission and the OPD of an optic are calculated as expected.

# %%
reload(poppy_optics)
from poppy_optics import *
clear_output()

# array_optic = poppy.fixed_sampling_optic(circ_pupil, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(multi_circ_pupil, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(rect_pupil, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(hex_pupil_side, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(multi_hex_pupil_flat, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(sec_obs, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(asym_sec_obs, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(compound_pupil, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(m1, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(thin_lens, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(gauss_ap, fwf, oversample)
array_optic = poppy.fixed_sampling_optic(zern_wfe, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(kol_wfe, fwf, oversample)
# array_optic = poppy.fixed_sampling_optic(psd_wfe, fwf, oversample)

misc.myimshow2(array_optic.amplitude, array_optic.opd, 
               pxscl1=array_optic.pixelscale, pxscl2=array_optic.pixelscale)
# Out:
# DEBUG:poppy:Converting Zernike WFE to fixed sampling with grid_size=9.6 m, npix=1024, oversample=4
# DEBUG:poppy:retrieving oversampled opd and transmission arrays
# INFO:poppy:Computing opd for Zernike WFE sampled onto 4096 pixel grid with pixelscale 0.00234375 m / pix
# INFO:poppy:Computing amplitude for Zernike WFE sampled onto 4096 pixel grid with pixelscale 0.00234375 m / pix
# DEBUG:poppy:binning down opd and transmission arrays

# %%
multi_hex_pupil_flat.display()
# Out:
# INFO:poppy:Computing intensity for MultiHex sampled onto 512 pixel grid with pixelscale 0.00560546875 m / pix
# DEBUG:poppy:Display pixel scale = 0.00560546875 m / pix
# <AxesSubplot:title={'center':'Transmittance for MultiHex'}, ylabel='[meters]'>

# %% [markdown]
# # Test the use of Deformable Mirrors.

# %%
# Deformable Mirror Tests
array_optic = poppy.fixed_sampling_optic(DM, fwf_dm, oversample)
misc.myimshow2(array_optic.amplitude, array_optic.opd, 
               pxscl1=array_optic.pixelscale, pxscl2=array_optic.pixelscale)

array_optic = poppy.fixed_sampling_optic(circ_seg_DM, fwf_dm)
misc.myimshow2(array_optic.amplitude, array_optic.opd, 
               pxscl1=array_optic.pixelscale, pxscl2=array_optic.pixelscale)

array_optic = poppy.fixed_sampling_optic(hex_seg_DM, fwf_dm)
misc.myimshow2(array_optic.amplitude, array_optic.opd, 
               pxscl1=array_optic.pixelscale, pxscl2=array_optic.pixelscale)

circ_seg_DM.set_actuator(1, -2.5e-7, 0, 0)
circ_seg_DM.set_actuator(2, 3e-7, 0.1*u.milliradian, 0)
circ_seg_DM.set_actuator(5, 0, 0.1*u.milliradian, 0.1*u.milliradian)

opd = circ_seg_DM.get_opd(fwf_dm)
misc.myimshow(opd)

hex_seg_DM.set_actuator(1, -2.5e-7, 0, 0)
hex_seg_DM.set_actuator(2, 3e-7, 0.1*u.milliradian, 0)
hex_seg_DM.set_actuator(5, 0, 0.1*u.milliradian, 0.1*u.milliradian)

opd = hex_seg_DM.get_opd(fwf_dm)
misc.myimshow(opd)
# Out:
# DEBUG:poppy:Converting DM to fixed sampling with grid_size=0.1852 m, npix=1024, oversample=4
# DEBUG:poppy:retrieving oversampled opd and transmission arrays
# INFO:poppy:Computing opd for DM sampled onto 4096 pixel grid with pixelscale 4.521484375e-05 m / pix
# INFO:poppy:Computing amplitude for DM sampled onto 4096 pixel grid with pixelscale 4.521484375e-05 m / pix
# DEBUG:poppy:binning down opd and transmission arrays
# DEBUG:poppy:Converting CircSegDM to fixed sampling with grid_size=0.1852 m, npix=1024, oversample=2
# DEBUG:poppy:retrieving oversampled opd and transmission arrays
# INFO:poppy:Computing opd for CircSegDM sampled onto 2048 pixel grid with pixelscale 9.04296875e-05 m / pix
# INFO:poppy:Computing amplitude for CircSegDM sampled onto 2048 pixel grid with pixelscale 9.04296875e-05 m / pix
# DEBUG:poppy:binning down opd and transmission arrays
# DEBUG:poppy:Converting HexDM to fixed sampling with grid_size=0.1852 m, npix=1024, oversample=2
# DEBUG:poppy:retrieving oversampled opd and transmission arrays
# INFO:poppy:Computing opd for HexDM sampled onto 2048 pixel grid with pixelscale 9.04296875e-05 m / pix
# INFO:poppy:Computing amplitude for HexDM sampled onto 2048 pixel grid with pixelscale 9.04296875e-05 m / pix
# DEBUG:poppy:binning down opd and transmission arrays

# %% [markdown]
# # Create the FresnelOpticalSystem and calculate a PSF.
# A variety of optics can be added by just commenting out or uncommenting some lines. This is useful for testing each optic in an actual system to make sure it functions as expected during propagation.

# %%
poppy.conf.use_cupy = True
# reload(poppy.fresnel)
# reload(poppy.geometry)
# reload(poppy.optics)
# reload(poppy)

# %%
reload(poppy_optics)
from poppy_optics import *
clear_output()

# Add the pupil optic(s)
fosys.add_optic(circ_pupil)
# fosys.add_optic(multi_circ_pupil)
# fosys.add_optic(rect_pupil)
# fosys.add_optic(square_pupil)
# fosys.add_optic(hex_pupil_side)
# fosys.add_optic(hex_pupil_flat)
# fosys.add_optic(multi_hex_pupil_side)
# fosys.add_optic(multi_hex_pupil_flat)
# fosys.add_optic(ngon_pupil)
# fosys.add_optic(sec_obs)
# fosys.add_optic(asym_sec_obs)
# fosys.add_optic(compound_pupil)

# fosys.add_optic(rpupil_array)
# fosys.add_optic(rprimary_opd_array)
# fosys.add_optic(rpupil_opd_array)
# fosys.add_optic(rpupil); fosys.add_optic(rprimary_opd)
# fosys.add_optic(rpupil_opd)

# Add a miscellaneous optic for testing
# fosys.add_optic(thin_lens)
# fosys.add_optic(gauss_ap)
# fosys.add_optic(knife_edge)
# fosys.add_optic(inv_circ)
# fosys.add_optic(scalar_opd)

# Add WFE optic for testing
fosys.add_optic(zern_wfe)
# fosys.add_optic(sin_wfe)
# fosys.add_optic(kol_wfe)
# fosys.add_optic(psd_wfe)
# fosys.add_optic(power_spec_wfe)

fosys.add_optic(m1)
fosys.add_optic(m2, distance=d_pri_sec)
fosys.add_optic(angular_focal_plane, distance=d_sec_to_focus)
# fosys.add_detector(pixelscale=5e-6*u.m/u.pixel, fov_pixels=64*u.pixel, distance=d_sec_to_focus)

poppy_log.disabled = False

psf, wfs = fosys.calc_psf(wavelength=wavelength, return_intermediates=True)

misc.myimshow2(wfs[-1].intensity, wfs[-1].phase, npix=64, lognorm1=True,
               pxscl1=wfs[-1].pixelscale, pxscl2=wfs[-1].pixelscale)
# Out:
# INFO:poppy:Added optic: Circle, radius=1.2 m after separation: 0.00e+00 m
# INFO:poppy:Added optic: Zernike WFE after separation: 0.00e+00 m
# INFO:poppy:Added optic: Primary after separation: 0.00e+00 m
# INFO:poppy:Added optic: Secondary after separation: 4.91e+00 m
# INFO:poppy:Added optic: Focus after separation: 6.39e+00 m
# INFO:poppy:Calculating PSF with 1 wavelengths
# INFO:poppy:User requested saving intermediate wavefronts in call to poppy.calc_psf
# DEBUG:poppy:Already loaded wisdom prior to this calculation, not reloading.
# INFO:poppy: Propagating wavelength = 5e-07 m
# DEBUG:poppy:Padded WF array for oversampling by 4.000, to (1024, 1024).
# DEBUG:poppy:Input wavefront has wavelength=0.5 microns, npix=256, diam=2.4 m, pixel scale=0.009375 m / pix
# DEBUG:poppy:  Propagating wavefront to Optic: Circle, radius=1.2 m after distance 0.0 m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Circle, radius=1.2 m
# DEBUG:poppy:normalizing at first plane (entrance pupil) to 1.0 total intensity
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Zernike WFE after distance 0.0 m
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Zernike WFE
# DEBUG:poppy:  Propagating wavefront to Lens: Primary, with focal length 5.52085 m after distance 0.0 m
# DEBUG:poppy:------ Applying Lens: Primary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.200e+00 m, z_w0=0.000e+00 m
# z=0.000e+00 m, z_r=9.048e+06 m
# DEBUG:poppy:  Beam radius at Primary =1.20e+00 m
# DEBUG:poppy: input flat wavefront and Primary has output beam curvature of =-5.52e+00 m
# DEBUG:poppy:Primary has a curvature of =-5.52e+00 m
# DEBUG:poppy:Primary has a curved output wavefront, with waist at 5.520849999997944 m
# DEBUG:poppy:Post Optic Parameters:w_0:7.322e-07 m, z_w0=5.521e+00 m
# z=0.000e+00 m, z_r=3.369e-06 m
# DEBUG:poppy:Set output beam focal length to 5.52085 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =1.48e+13 m
# DEBUG:poppy:Applying spherical lens phase =6.75e-14 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Primary
# DEBUG:poppy:------ Optic: Primary applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: Secondary, with focal length -0.6790325 m after distance 4.907028205 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.520849999997944 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.009375 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=5.520849999997944 m
# DEBUG:poppy:using cupy (GPU) FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.000147 s, full function  in 0.001 s
# DEBUG:poppy:Applying spherical phase curvature =5.52e+00 m
# DEBUG:poppy:Applying spherical lens phase =1.81e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.875442708332263e-07 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.6138217949979445 m
# DEBUG:poppy:Applying spherical phase curvature =-6.14e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.63e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using cupy (GPU) FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.000065 s, full function  in 0.000 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 4.91e+00 m ------
# DEBUG:poppy:------ Applying Lens: Secondary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:7.322e-07 m, z_w0=5.521e+00 m
# z=4.907e+00 m, z_r=3.369e-06 m
# DEBUG:poppy:  Beam radius at Secondary =1.33e-01 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:7.322e-07 m, z_w0=5.521e+00 m
# z=4.907e+00 m, z_r=3.369e-06 m
# DEBUG:poppy: input curved wavefront and Secondary has output beam curvature of =-6.39e+00 m
# DEBUG:poppy:Secondary has a curvature of =-6.39e+00 m
# DEBUG:poppy:Secondary has a curved output wavefront, with waist at 11.2986926835285 m
# DEBUG:poppy:Post Optic Parameters:w_0:7.625e-06 m, z_w0=1.130e+01 m
# z=4.907e+00 m, z_r=3.653e-04 m
# DEBUG:poppy:Magnification: 10.412899234743197  from R_in = -0.6138217949979445 m, R_out = -6.3916644994027925 m
# DEBUG:poppy:Output beam focal length is now 57.48805474013198 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=-1.4727e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=-1.6291e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-1.5645e-01 1 / m
# DEBUG:poppy:Applying spherical phase curvature =2.17e+09 m
# DEBUG:poppy:Applying spherical lens phase =4.62e-10 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Secondary
# DEBUG:poppy:------ Optic: Secondary applied ------
# DEBUG:poppy:  Propagating wavefront to Image plane: Focus after distance 6.3919974 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.2986926835285 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=6.391664478528501 m
# DEBUG:poppy:using cupy (GPU) FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.000096 s, full function  in 0.000 s
# DEBUG:poppy:Applying spherical phase curvature =6.39e+00 m
# DEBUG:poppy:Applying spherical lens phase =1.56e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using cupy (GPU) FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.000063 s, full function  in 0.000 s
# DEBUG:poppy:using cupy (GPU) FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.000087 s, full function  in 0.000 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.13e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Image plane: Focus
# INFO:poppy:  Calculation completed in 0.076 s
# DEBUG:poppy:FFTW wisdom saved to /home/u21/kianmilani/.astropy/config/poppy_fftw_wisdom.json
# INFO:poppy:PSF Calculation completed.

# %% [markdown]
# # Show all waves

# %%
for i,wf in enumerate(wfs):
    if (i-len(wfs))==-1: n = 64
    else: n = npix
    misc.myimshow2(wf.intensity, wf.phase, npix=n, lognorm1=True,
                   pxscl1=wf.pixelscale, pxscl2=wf.pixelscale)
# Out:
# 0 0.009375 m / pix
# 1 0.009375 m / pix
# 2 0.009375 m / pix
# 3 0.0010423357504927451 m / pix
# 4 0.010742958623613921 arcsec / pix
